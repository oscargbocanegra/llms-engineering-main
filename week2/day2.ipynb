# %% [markdown]
# # Gradio Day!
#
# Today we will build User Interfaces using the outrageously simple Gradio framework.
#
# Prepare for joy!
#
# Please note: your Gradio screens may appear in 'dark mode' or 'light mode' depending on your computer settings.

# %%
#%pip install gradio

# %%
# Import required libraries
from IPython.display import Markdown, display
import gradio as gr # oh yeah!

# %%
# %run ../config/llm_settings.py

# %%
# %run ../utils/llm_functions.py

# %%
validaciones = validate_loaded_clients()

validaciones
# Out:
# {'ollama': {'provider': 'ollama',
#   'model': 'gemma4:12b',
#   'client_loaded': True,
#   'model_configured': True,
#   'connection_test': 'SKIPPED',
#   'status': 'PASSED',
#   'error': None},
#  'nvidia': {'provider': 'nvidia',
#   'model': 'z-ai/glm-5.2',
#   'client_loaded': True,
#   'model_configured': True,
#   'connection_test': 'SKIPPED',
#   'status': 'PASSED',
#   'error': None},
#  'openai': {'provider': 'openai',
#   'model': 'gpt-4o-mini',
#   'client_loaded': True,
#   'model_configured': True,
#   'connection_test': 'SKIPPED',
#   'status': 'PASSED',
#   'error': None},
#  'anthropic': {'provider': 'anthropic',
#   'model': 'claude-opus-4-1-20250805',
#   'client_loaded': True,
#   'model_configured': True,
#   'connection_test': 'SKIPPED',
#   'status': 'PASSED',
#   'error': None},
#  'google': {'provider': 'google',
#   'model': 'gemini-2.5-flash-lite',
#   'client_loaded': True,
#   'model_configured': True,
#   'connection_test': 'SKIPPED',
#   'status': 'PASSED',
#   'error': None}}

# %%
# Message generic system
system_message = "You are a helpful assistant"
prompt= "What is today's date?"

# %%
# This can reveal the "training cut off", or the most recent date in the training data
response_olama = call_ollama(
    system_msg=system_message,
    user_msg=prompt,
    max_tokens=1000,
    #stream=True,
    )

# %%
response_olama
# Out:
# "Today's date is Monday, May 20, 2024."

# %% [markdown]
# ## User Interface time!
#
# **IMPORTANTE para Docker/JupyterLab:**
# - Gradio no se muestra inline, debes abrir manualmente en el navegador
# - Usa diferentes puertos para cada demo (7860, 7861, 7862, etc.)
# - Accede a: `http://192.168.80.200:PUERTO`
# - Cierra las demos anteriores con `gr.close_all()` si necesitas reutilizar el puerto

# %%
# here's a simple function

def shout(text):
    #print(f"Shout has been called with input {text}")
    return text.upper()

# %%
shout("hello")
# Out:
# 'HELLO'

# %%
# Cerrar todas las instancias previas de Gradio
gr.close_all()

demo = gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never")
demo.launch(share=True)
#demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://c9b1b9011a4e62c83b.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c9b1b9011a4e62c83b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Cerrar todas las instancias previas de Gradio y abre en un navegador independiente gradio con .launch(inbrowser=True)
gr.close_all()

gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never").launch(share=True, inbrowser=True)
# Out:
# Closing server running on port: 7860
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://fbb63839aa5d203d3f.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fbb63839aa5d203d3f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Adding authentication
#
# Gradio makes it very easy to have userids and passwords
#
# Obviously if you use this, have it look properly in a secure place for passwords! At a minimum, use your .env

# %%
gr.close_all()
gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never").launch(share=True, inbrowser=True, auth=("ed", "bananas"))
# Out:
# Closing server running on port: 7860
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://c59c433d9641ec6d19.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c59c433d9641ec6d19.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Forcing dark mode
#
# Gradio appears in light mode or dark mode depending on the settings of the browser and computer. There is a way to force gradio to appear in dark mode, but Gradio recommends against this as it should be a user preference (particularly for accessibility reasons). But if you wish to force dark mode for your screens, below is how to do it.

# %%
# Define this variable and then pass js=force_dark_mode when creating the Interface
gr.close_all()

force_dark_mode = """
function refresh() {
    const url = new URL(window.location);
    if (url.searchParams.get('__theme') !== 'dark') {
        url.searchParams.set('__theme', 'dark');
        window.location.href = url.href;
    }
}
"""
gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never", js=force_dark_mode).launch(share=True)

# %%
responder = make_gradio_responder(
    provider="ollama",
    system_message=(
        "Eres un asistente útil. "
        "Responde siempre en español."
    ),
    max_tokens=1000,
    temperature=0.7,
)

# %%
gr.close_all()

view = gr.Interface(
    fn=responder,
    title="Chat con Ollama",
    inputs=gr.Textbox(
        label="Tu mensaje",
        lines=6,
    ),
    outputs=gr.Textbox(
        label="Respuesta",
        lines=10,
    ),
    flagging_mode="never",
)

view.launch(share=True)
# Out:
# Closing server running on port: 7860
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://8156c6326618e15217.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8156c6326618e15217.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Chat multiprovider (Ollama, NVIDIA NIM, OpenAI, Anthropic Claude o Google Gemini.)

# %%
def responder_llm2(
    prompt: str,
    provider: str,
    max_tokens: int,
    temperature: float,
) -> str:
    """
    Adaptador entre Gradio y call_provider.

    Gradio entrega los valores de sus componentes y esta función
    normaliza y valida los argumentos antes de invocar al proveedor.
    """
    prompt = (prompt or "").strip()
    provider = (provider or "").strip().lower()

    if not prompt:
        return "Escribe un mensaje antes de enviar."

    try:
        max_tokens = int(max_tokens)

        if max_tokens < 1:
            return "max_tokens debe ser mayor que cero."

        temperature = float(temperature)

        if not 0.0 <= temperature <= 2.0:
            return "temperature debe estar entre 0.0 y 2.0."

        result = call_provider(
            provider=provider,
            system_msg=system_message,
            user_msg=prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            stream=False,
            display_output=False,
        )

        if result is None:
            raise RuntimeError(
                f"El proveedor '{provider}' no devolvió contenido."
            )

        result = str(result).strip()

        if not result:
            return f"El proveedor '{provider}' devolvió una respuesta vacía."

        return result

    except Exception as error:
        return (
            f"Error al consultar el proveedor '{provider}': "
            f"{type(error).__name__}: {error}"
        )

# %%
gr.close_all()

view = gr.Interface(
    fn=responder_llm2,
    title="Chat multiproveedor",
    inputs=[
        gr.Textbox(label="Tu mensaje", lines=6),
        gr.Dropdown(
            choices=[
                ("Ollama", "ollama"),
                ("NVIDIA NIM", "nvidia"),
                ("OpenAI", "openai"),
                ("Anthropic Claude", "anthropic"),
                ("Google Gemini", "google"),
            ],
            value="ollama",
            label="Proveedor",
        ),
        gr.Slider(
            minimum=1,
            maximum=4096,
            value=1000,
            step=1,
            label="Máximo de tokens",
        ),
        gr.Slider(
            minimum=0.0,
            maximum=2.0,
            value=0.7,
            step=0.1,
            label="Temperatura",
        ),
    ],
    outputs=gr.Textbox(label="Respuesta", lines=12),
    flagging_mode="never",
)

view.launch(share=True)
# Out:
# Closing server running on port: 7860
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://4cf7b937ed1fc4e470.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4cf7b937ed1fc4e470.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Chat con respuesta en formato MArkdown

# %%
system_message = "Eres un asistente util que responde en formato markdown"

# %%
responder = make_gradio_responder(
    provider="nvidia",
    system_message=system_message,
    max_tokens=1000,
    temperature=0.7,
)

# %%
# Adding a little more: with call Ollama
gr.close_all()

view = gr.Interface(
    fn=responder,
    title="Shout", 
    inputs=[gr.Textbox(label="Your message")], 
    outputs=[gr.Markdown(label="Response")],
    flagging_mode="never"
    )
view.launch(share=True)
# Out:
# Closing server running on port: 7860
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://2e1b0470c599f594bc.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2e1b0470c599f594bc.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## And now getting fancy
#
# Remember to check the Intermediate Python Guide if you're unsure about generators and "yield"

# %%
def responder_stream(prompt: str):
    prompt = (prompt or "").strip()

    if not prompt:
        yield "Escribe un mensaje."
        return

    messages = [{"role": "system","content": system_message,},
                {"role": "user","content": prompt,},
                ]

    response = ollama_client.chat.completions.create(
        model=OLLAMA_MODEL,
        messages=messages,
        max_tokens=1000,
        temperature=0.7,
        stream=True,
    )

    respuesta_completa = ""

    for chunk in response:
        fragmento = chunk.choices[0].delta.content or ""

        if fragmento:
            respuesta_completa += fragmento
            yield respuesta_completa

# %%
gr.close_all()

view = gr.Interface(
    fn=responder_stream,
    title="Chat con Ollama — Streaming",
    inputs=gr.Textbox(
        label="Tu mensaje",
        lines=6,
        placeholder="Escribe aquí...",
    ),
    outputs=gr.Textbox(
        label="Respuesta",
        lines=12,
    ),
    flagging_mode="never",
)

view.queue()

view.launch(share=True)
# Out:
# Closing server running on port: 7860
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://2b606abd920b667fab.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2b606abd920b667fab.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Building a company brochure generator
#
# Now you know how - it's simple!

# %%
from scraper import fetch_website_contents

# %%
# Again this is typical Experimental mindset - I'm changing the global variable we used above:

system_message = """
You are an assistant that analyzes the contents of a company website landing page
and creates a short brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
"""

# %%
def stream_brochure(company_name, url, model):
    yield ""
    prompt = f"Please generate a company brochure for {company_name}. Here is their landing page:\n"
    prompt += fetch_website_contents(url)
    if model=="GPT":
        result = stream_gpt(prompt)
    elif model=="Claude":
        result = stream_claude(prompt)
    else:
        raise ValueError("Unknown model")
    yield from result

# %%
name_input = gr.Textbox(label="Company name:")
url_input = gr.Textbox(label="Landing page URL including http:// or https://")
model_selector = gr.Dropdown(["GPT", "Claude"], label="Select model", value="GPT")
message_output = gr.Markdown(label="Response:")
gr.close_all()

view = gr.Interface(
    fn=stream_model,
    title="Brochure Generator", 
    inputs=[name_input, url_input, model_selector], 
    outputs=[message_output], 
    examples=[
            ["Hugging Face", "https://huggingface.co", "GPT"],
            ["Edward Donner", "https://edwarddonner.com", "Claude"]
        ], 
    flagging_mode="never"
    )
view.launch(share=True)

# %%
gr.close_all()
