# %% [markdown]
# # Welcome to the Day 2 Lab!

# %%
# Installers
import sys
# Uncomment to install required packages
#!{sys.executable} -m pip install requests

# %%
# imports
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from dotenv import load_dotenv
from scraper import fetch_website_contents
import os

# %%
# Constantes
# Path to global .env file in the conda project root
global_env_path = '/workspace/.env'
load_dotenv(dotenv_path=global_env_path, override=True)

ollama_base_url = os.getenv('OLLAMA_BASE_URL')
ollama_api_key = os.getenv('OLLAMA_API_KEY')

# %%
OLLAMA_API = ollama_base_url+"/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = os.getenv('OLLAMA_MODEL')
print (OLLAMA_API)
print (MODEL)
# Out:
# http://192.168.80.200:11434/api/chat
# deepseek-v3.1:671b-cloud

# %%
# Crea una lista de mensajes utilizando el mismo formato que usamos para OpenAI
messages = [
    {"role": "user", "content": "Describe algunas de las aplicaciones comerciales de la IA generativa."}
]

# %%
payload = {
    "model": MODEL,
    "messages": messages,
    "stream": False
}

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# ¡Por supuesto! La IA generativa ha dejado de ser una tecnología experimental para convertirse en un motor de innovación y eficiencia en múltiples industrias. Sus aplicaciones comerciales son vastas y se centran en la creatividad, la automatización, la personalización y la optimización.
#
# Aquí te describo algunas de las aplicaciones más destacadas, agrupadas por áreas funcionales:
#
# ### 1. Marketing y Publicidad
# Esta es una de las áreas donde más impacto ha tenido, democratizando la creación de contenido.
#
# *   **Creación de Contenido Escrito:** Generación automática de copias para anuncios, emails marketing, descripciones de productos, entradas de blog y publicaciones para redes sociales. Herramientas como Jasper o Copy.ai son ejemplos.
# *   **Diseño Gráfico y Visuales:** Creación de imágenes, banners publicitarios y conceptos artísticos a partir de descripciones textuales. Midjourney, DALL-E y Stable Diffusion permiten a las marcas producir assets visuales de forma rápida y barata.
# *   **Publicidad Hiper-Personalizada:** Generación de variantes de un mismo anuncio (imagen y texto) adaptadas a diferentes audiencias o segmentos demográficos, optimizando así las campañas.
#
# ### 2. Ventas y Atención al Cliente (Customer Experience)
# La IA generativa mejora la interacción con el cliente en varios puntos de contacto.
#
# *   **Chatbots y Asistentes Virtuales Avanzados:** Van más allá de respuestas preprogramadas. Pueden mantener conversaciones fluidas y contextuales, resolver consultas complejas y ofrecer recomendaciones personalizadas en tiempo real.
# *   **Resumen de Conversaciones:** Automatizar la creación de resúmenes después de una llamada con un cliente o una reunión de ventas, extrayendo puntos clave, acuerdos y acciones pendientes.
# *   **Personalización de Ofertas:** Generar correos electrónicos o mensajes de ventas altamente personalizados para cada lead o cliente, basándose en su historial de compras y comportamiento.
#
# ### 3. Diseño de Productos e Ingeniería
# Acelera los procesos de ideación y prototipado.
#
# *   **Diseño Generativo:** En sectores como la automoción, aeronáutica o bienes de consumo, la IA puede generar miles de diseños de componentes optimizando para parámetros como peso, resistencia, uso de materiales o coste. Por ejemplo, diseñar una pieza de avión más ligera que mantenga su integridad estructural.
# *   **Moda y Retail:** Crear diseños de ropa, estampados y accesorios nuevos. También se usa para generar imágenes de modelos virtuales con diferentes tallas y características, reduciendo la necesidad de costosas sesiones fotográficas.
#
# ### 4. Software y Tecnología
# Revoluciona la forma en que se desarrolla y mantiene el código.
#
# *   **Asistentes de Codificación (Code Completion):** Herramientas como GitHub Copilot sugieren líneas o bloques completos de código en función del contexto, aumentando drásticamente la productividad de los desarrolladores y reduciendo errores.
# *   **Generación de Código a partir de Descripciones:** Convertir instrucciones en lenguaje natural (por ejemplo, "crea una función que calcule el promedio de una lista") en código funcional en varios lenguajes de programación.
# *   **Pruebas Automatizadas (QA):** Generar casos de prueba automáticamente para asegurar la calidad del software.
#
# ### 5. Entretenimiento y Medios de Comunicación
# Está transformando la creación de contenido artístico y narrativo.
#
# *   **Guionización y Narrativa:** Ayudar a escritores y guionistas a generar ideas, tramas alternativas, diálogos o incluso borradores iniciales.
# *   **Música y Audio:** Componer bandas sonoras, jingles o efectos de sonido personalizados para videojuegos, podcasts y producciones audiovisuales.
# *   **Generación de Video:** Crear videos cortos a partir de guiones o prompts de texto, útil para crear contenido para redes sociales o trailers. También permite la edición avanzada, como cambiar fondos o doblar voces de forma realista.
#
# ### 6. Ciencia e Investigación
# Acelera el descubrimiento y la innovación.
#
# *   **Descubrimiento de Fármacos:** Diseñar moléculas virtuales con propiedades específicas para acelerar la investigación de nuevos medicamentos, reduciendo costes y tiempo.
# *   **Investigación de Materiales:** Similar al diseño generativo, pero a nivel molecular, para descubrir nuevos materiales con propiedades deseadas (como mejores baterías o superconductores).
#
# ### 7. Operaciones Empresariales y Formación
# Optimiza procesos internos.
#
# *   **Resumen de Documentos:** Sintetizar informes largos, actas de reuniones o documentos legales en resúmenes ejecutivos con los puntos clave.
# *   **Formación y Onboarding:** Crear simulaciones y escenarios de entrenamiento hiperrealistas y personalizados para empleados. Por ejemplo, generar diálogos para un simulador de atención al cliente.
#
# ---
#
# ### Consideraciones Importantes:
#
# El uso comercial de la IA generativa no está exento de desafíos. Las empresas deben considerar:
#
# *   **Sesgos (Bias):** Los modelos se entrenan con datos existentes que pueden contener sesgos, lo que podría generar contenido no deseado o discriminatorio.
# *   **Calidad y Control:** El contenido generado no siempre es perfecto y requiere supervisión y edición humana (concepto de "human-in-the-loop").
# *   **Propiedad Intelectual y Legal:** Surgen dudas sobre quién es el propietario de una obra creada por IA y la posible infracción de derechos de autor de los datos de entrenamiento.
# *   **Seguridad y "Alucinaciones":** Los modelos a veces "alucinan", es decir, inventan información o hechos que parecen verídicos pero no lo son, lo que es un riesgo crítico en áreas como la legal o médica.
#
# En resumen, la IA generativa se está consolidando como una **tecnología de propósito general** que está redefiniendo los procesos creativos y operativos en casi todos los sectores, impulsando la eficiencia, la personalización y la innovación.

# %% [markdown]
# ### Para este caso el ejercicio es aplicar el resumen del dia 1 con Ollama

# %%
article = "https://wordpress.org/documentation/article/password-best-practices/"

# %%
# Let's try out this utility

art = fetch_website_contents(article)
print(art)
# Out:
# Password Best Practices – Documentation – WordPress.org
#
# WordPress.org
# News
# Showcase
# Hosting
# Extend
# Themes
# Plugins
# Patterns
# Blocks
# Openverse
# ↗
# ︎
# Learn
# Learn WordPress
# Documentation
# Forums
# Developers
# WordPress.tv
# ↗
# ︎
# Community
# Make WordPress
# Photo Directory
# Five for the Future
# Events
# Job Board
# ↗
# ︎
# About
# About WordPress
# Enterprise
# Gutenberg
# ↗
# ︎
# Swag Store
# ↗
# ︎
# Get WordPress
# Search in WordPress.org
# Get WordPress
# WordPress.org
# Documentation
# Password Best Practices
# WordPress Overview
# Technical Guides
# Support Guides
# Customization
# Get Involved
# WordPress Overview
# Technical Guides
# Support Guides
# Customization
# Get Involved
# Home
# Technical guides
# Security
# Password Best Practices
# Search documentation
# Password Best Practices
# In this article
# Table of Contents
# More about special characters
# Things you should absolutely avoid
# Automatically generated passwords in WordPress
# Keeping track of your passwords
# Other security recommendations
# Two factor authentication
# Usernames
# Changelog
# ↑
# Back to top
# Securing your WordPress starts with a strong password. A strong password is complex and elaborate. It isn’t easy to guess since it doesn’t contain recognizable words, names, dates or numbers. You shouldn’t pick a password containing less than 20 characters. It can be hard though to remember a random string of letters, numbers and special characters. But in general, the more characters and complexity, the better.
# Here are some suggested guidelines when creating a strong password:
# At least 20 characters (preferably more)
# Use lowercase and uppercase
# Containing numbers
# Containing special characters such as
# `!"#$%&'()*+,-./:;<=>?@[]^_{}|~``
# More about special characters
# a backslash
# \
# is not allowed
# many typographical characters like elegant quotes, ligatures, letters with accents and mathematical symbols are allowed (by WordPress) in passwords, but not recommended. Some characters are hard to recognize. Many characters are harder or sometimes impossible to type on a device. The characters can not be s

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarkyassistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(art)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarkyassistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nPassword Best Practices – Documentation – WordPress.org\n\nWordPress.org\nNews\nShowcase\nHosting\nExtend\nThemes\nPlugins\nPatterns\nBlocks\nOpenverse\n↗\n︎\nLearn\nLearn WordPress\nDocumentation\nForums\nDevelopers\nWordPress.tv\n↗\n︎\nCommunity\nMake WordPress\nPhoto Directory\nFive for the Future\nEvents\nJob Board\n↗\n︎\nAbout\nAbout WordPress\nEnterprise\nGutenberg\n↗\n︎\nSwag Store\n↗\n︎\nGet WordPress\nSearch in WordPress.org\nGet WordPress\nWordPress.org\nDocumentation\nPassword Best Practices\nWordPress Overview\nTechnical Guides\nSupport Guides\nCustomization\nGet Involved\nWordPress Overview\nTechnical Guides\nSupport Guides\nCustomization\nGet Involved\nHome\nTechnical guides\nSecurity\nPassword Best Practices\nSearch documentation\nPassword Best Practices\nIn this article\nTable of Contents\nMore about special characters\nThings you should absolutely avoid\nAutomatically generated passwords in WordPress\nKeeping track of your passwords\nOther security recommendations\nTwo factor authentication\nUsernames\nChangelog\n↑\nBack to top\nSecuring your WordPress starts with a strong password. A strong password is complex and elaborate. It isn’t easy to guess since it doesn’t contain recognizable words, names, dates or numbers. You shouldn’t pick a password containing less than 20 characters. It can be hard though to remember a random string of letters, numbers and special characters. But in general, the more characters and complexity, the better.\nHere are some suggested guidelines when creating a strong password:\nAt least 20 characters (preferably more)\nUse lowercase and uppercase\nContaining numbers\nContaining special characters such as\n`!"#$%&\'()*+,-./:;<=>?@[]^_{}|~``\nMore about special characters\na backslash\n\\\nis not allowed\nmany typographical characters like elegant quotes, ligatures, letters with accents and mathematical symbols are allowed (by WordPress) in passwords, but not recommended. Some characters are hard to recognize. Many characters are harder or sometimes impossible to type on a device. The characters can not be s'}]

# %%
# Call Ollama API to summarize website content

def summarize(url):
    website = fetch_website_contents(url)
    
    # Create the payload with the website content
    payload = {
        "model": MODEL,
        "messages": messages_for(website),
        "stream": False
    }
    
    # Call Ollama API
    response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
    
    # Extract and return the content from the response
    return response.json()['message']['content']

# %%
summarize(article)
# Out:
# '# Password Best Practices: Because "password123" Isn\'t Cutting It Anymore\n\nThe WordPress documentation is here to save you from yourself with some *riveting* password advice. Apparently "admin" and "123456" aren\'t the fortress-like security measures we all thought they were.\n\n**Key Takeaways:**\n- Your password should be longer than your last relationship (20+ characters minimum)\n- Throw in some uppercase, lowercase, numbers, and symbols - basically everything except your social security number\n- Special characters are allowed, but apparently backslashes are the party crashers nobody wants\n- Pro tip: Don\'t use passwords that actual humans can remember (that\'s what password managers are for)\n\n**Most Important Warning:** Avoid using anything that might actually be guessable. So basically, forget everything you\'ve ever done since creating your first AOL account in 1998.\n\nThe document trails off mid-sentence about special characters being hard to type - perhaps the author gave up trying to create their own recommended password and went for a coffee break instead. ☕'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))
