# %% [markdown]
# Auxiliar LLM

# %%
#%pip install -U \
#  langchain==1.2.7 \
#  langchain-core==1.2.7 \
#  langchain-openai==1.1.7 \
#  langchain-community==0.4.1 \
#  langchain-text-splitters==1.1.0 \
#  langchain-chroma==1.1.0

# %%
from importlib.metadata import version

print("langchain-core:", version("langchain-core"))
print("langchain-openai:", version("langchain-openai"))
print("langchain:", version("langchain"))
print("langchain-community:", version("langchain-community"))
print("langchain-text-splitters:", version("langchain-text-splitters"))
print("langchain-chroma:", version("langchain-chroma"))

# %% [markdown]
# En notebooks a veces queda un módulo viejo en memoria aunque hayas actualizado.
# Debe ser 0 o muy pocos (idealmente 0 antes de tus imports).

# %%
import sys
mods = [m for m in sys.modules.keys() if m.startswith("langchain")]
print("langchain modules pre-cargados:", len(mods))

# %%
import sys
print(sys.executable)

import pip
print(pip.__version__)

# %%
# !which python
# !which pip

# %%
/jarvis explicame este codigo

import sys
# !{sys.executable} -m pip -V
# !{sys.executable} -m pip show langchain-openai langchain-core
# Out:
# ```markdown
# # Explicación del Código Proporcionado
#
# ```python
# import sys
# !/home/jovyan/.venv/llm/bin/python -m pip -V
# !/home/jovyan/.venv/llm/bin/python -m pip show langchain-openai langchain-core
# ```
#
# ## Desglose y Funcionalidad de Cada Línea
#
# ### 1. Importación del Módulo `sys`
#
# ```python
# import sys
# ```
#
# - **Propósito**: El módulo `sys` proporciona acceso a algunas variables usadas o mantenidas por el intérprete Python y a funciones que interactúan fuertemente con el intérprete.
# - **Uso en este Código**: En este fragmento específico, el uso de `sys` no es evidente porque no se utiliza ninguna función o variable del módulo `sys`. Su presencia podría sugerir futuras operaciones relacionadas con el sistema o la gestión del entorno Python.
#
# ### 2. Ejecución de un Comando de Sistema para Verificar la Versión de `pip`
#
# ```python
# !/home/jovyan/.venv/llm/bin/python -m pip -V
# ```
#
# - **`!` Operator**: En algunos entornos interactivos (como Jupyter Notebooks), el operador `!` permite ejecutar comandos del sistema operativo directamente desde la celda de código.
# - **Comando Executado**:
#   - **`/home/jovyan/.venv/llm/bin/python`**: Ruta al intérprete Python específico. Aquí, se asume que estás trabajando en un entorno virtual (`llm`) ubicado en `/home/jovyan/.venv`.
#   - **`-m pip`**: Indica a Python que ejecute el módulo `pip`, que es la herramienta de gestión de paquetes de Python.
#   - **`-V`**: Opción para mostrar la versión de `pip`. Esto es útil para asegurarse de que estás utilizando la versión correcta de `pip`.
#
# **Ejemplo de Salida:**
# ```bash
# pip 23.1.2 from /home/jovyan/.venv/llm/lib/python3.8/site-packages/pip (python 3.8)
# ```
#
# ### 3. Ejecución de un Comando de Sistema para Mostrar Información sobre Paquetes Específicos
#
# ```python
# !/home/jovyan/.venv/llm/bin/python -m pip show langchain-openai langchain-core
# ```
#
# - **Comando Executado**:
#   - Utiliza el mismo intérprete Python y módulo `pip` que en la línea anterior.
#   - **`show`**: Subcomando de `pip` que muestra información detallada sobre los paquetes especificados (`langchain-openai`, `langchain-core`).
#
# **Ejemplo de Salida:**
# ```bash
# Name: langchain-openai
# Version: 0.1.2
# Summary: Integración entre LangChain y OpenAI API.
# Home-page: https://github.com/langchain-ai/langchain-openai
# Author: LangChain Team
# Author-email: team@langchain.ai
# License: MIT
# Location: /home/jovyan/.venv/llm/lib/python3.8/site-packages
# Requires: langchain, openai, requests
# Required-by:
#
# ---
# Name: langchain-core
# Version: 0.1.5
# Summary: Núcleo de funcionalidades para LangChain.
# Home-page: https://github.com/langchain-ai/langchain-core
# Author: LangChain Team
# Author-email: team@langchain.ai
# License: MIT
# Location: /home/jovyan/.venv/llm/lib/python3.8/site-packages
# Requires: numpy, pandas, scikit-learn
# Required-by:
# ```
#
# ## Flujo General del Código
#
# 1. **Importación de `sys`**:
#    - Aunque no se utiliza en el resto del fragmento, esto podría preparar el entorno para posibles operaciones futuras que dependan de variables o funciones del módulo `sys`.
#
# 2. **Verificación de la Versión de `pip`**:
#    - Se asegura de que se está utilizando la versión correcta de `pip`. Esto es particularmente útil en entornos con múltiples versiones de Python y/o `pip` instaladas.
#
# 3. **Visualización de Información sobre Paquetes Específicos**:
#    - Proporciona detalles sobre los paquetes `langchain-openai` y `langchain-core`, incluyendo sus versiones, dependencias, ubicaciones y otros metadatos relevantes.
#    - Esto es útil para confirmar la instalación correcta de estos paquetes y asegurarse de que están utilizando las versiones esperadas.
#
# ## Posibles Consideraciones
#
# - **Dependencia del Entorno**:
#   - El camino específico `/home/jovyan/.venv/llm/bin/python` indica que este código está diseñado para ejecutarse en un entorno virtual (`llm`) ubicado en esa ruta. Si se ejecuta en un entorno diferente, el comando fallará.
#
# - **Compatibilidad**:
#   - Asegúrate de que las versiones del intérprete Python y `pip` sean compatibles con los paquetes que estás intentando utilizar (`langchain-openai`, `langchain-core`).
#
# - **Alternativas al Operador `!`**:
#   - En entornos que no soportan el operador `!`, puedes usar métodos alternativos para ejecutar comandos del sistema, como `subprocess.run()` o módulos específicos del entorno.
#
# ## Conclusión
#
# Este fragmento de código se enfoca en **verificar y proporcionar información** sobre la herramienta de gestión de paquetes (`pip`) y los paquetes específicos (`langchain-openai` y `langchain-core`) que estás utilizando en tu proyecto. Esto es una práctica común antes de comenzar a desarrollar o ejecutar código que depende de estos paquetes, asegurándose de que todo esté correctamente configurado y actualizado.
# ```

# %%
import sys
# !{sys.executable} -m pip install -U langchain-classic
# Out:
# Requirement already satisfied: langchain-classic in /home/jovyan/.venv/llm/lib/python3.11/site-packages (1.0.3)
# Collecting langchain-classic
#   Downloading langchain_classic-1.0.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting langchain-core<2.0.0,>=1.2.31 (from langchain-classic)
#   Downloading langchain_core-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-classic) (0.6.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-classic) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-classic) (2.0.48)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-classic) (25.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-classic) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-classic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-classic) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: anyio in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.12.1)
# Requirement already satisfied: certifi in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: idna in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /home/jovyan/.venv/llm/lib/python3.11/site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.3.2)
# Downloading langchain_classic-1.0.4-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.8 MB/s  0:00:00
# Downloading langchain_core-1.3.0-py3-none-any.whl (515 kB)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: langchain-core, langchain-text-splitters, langchain-classic
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.83
#     Uninstalling langchain-core-0.3.83:
#       Successfully uninstalled langchain-core-0.3.83
#   Attempting uninstall: langchain-text-splitters 0/3 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.3.11angchain-core]
#     Uninstalling langchain-text-splitters-0.3.11:0/3 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.3.11[langchain-core]
#   Attempting uninstall: langchain-classic━━━ 0/3 [langchain-core]
#     Found existing installation: langchain-classic 1.0.33 [langchain-core]
#     Uninstalling langchain-classic-1.0.3:1m╸━━━━━━━━━━━━━ 2/3 [langchain-classic]
#       Successfully uninstalled langchain-classic-1.0.3━━━━━━━━ 2/3 [langchain-classic]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [langchain-classic]langchain-classic]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.28 requires langchain-core<1.0.0,>=0.3.73, but you have langchain-core 1.3.0 which is incompatible.
# langchain 0.3.28 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.1.2 which is incompatible.
# Successfully installed langchain-classic-1.0.4 langchain-core-1.3.0 langchain-text-splitters-1.1.2

# %%
# install faiss-cpu!
# Mac users - this may fail if you don't have a recent version of MacOS
# In which case I recommend you skip this lab -- FAISS is not essential! (Or upgrade MacOS if you wish..)
import sys
# !{sys.executable} -m pip install -U faiss-cpu

# Or use !pip install if you're on the Original version of the course and you're not using uv

# %%
import faiss
print("FAISS import OK")

# %%
/jarvis explicame este codigo

from langchain_community.vectorstores import FAISS
print("OK: FAISS importado")
# Out:
# ```markdown
# # Explicación del Código Proporcionado
#
# ```python
# from langchain_community.vectorstores import FAISS
# print("OK: FAISS importado")
# ```
#
# ## Desglose y Funcionalidad de Cada Línea
#
# ### 1. Importación del Módulo `FAISS` desde `langchain_community.vectorstores`
#
# ```python
# from langchain_community.vectorstores import FAISS
# ```
#
# - **`from ... import ...`**: Esta sintaxis se utiliza para importar una clase o función específica (`FAISS`) desde un módulo o paquete.
# - **`langchain_community.vectorstores`**: Es el camino completo al módulo o paquete de donde se está importando `FAISS`.
#   - **`langchain_community`** probablemente es parte de un conjunto de bibliotecas o extensiones relacionadas con el procesamiento del lenguaje natural y la gestión de datos vectoriales.
#   - **`vectorstores`** indica que el módulo contiene herramientas para manejar almacenes de vectores, que son estructuras de datos utilizadas en aplicaciones como la búsqueda por similitud de documentos o el clustering de textos.
#
# - **`FAISS`**: Es una biblioteca desarrollada por Facebook AI Research (FAIR) diseñada para manejar grandes conjuntos de datos vectoriales de manera eficiente. Permite operaciones avanzadas como búsquedas k-nearest neighbors, clustering y representación de datos en espacios multidimensionales.
#
# ### 2. Impresión de un Mensaje Confirmatorio
#
# ```python
# print("OK: FAISS importado")
# ```
#
# - **`print(...)`**: Función utilizada para imprimir texto en la consola o salida estándar.
# - **Mensaje**:
#   - `"OK: FAISS importado"` es una cadena que se muestra en la consola después de que `FAISS` ha sido exitosamente importado.
#
# ## Flujo General del Código
#
# 1. **Importación de `FAISS`**:
#    - Se intenta cargar y utilizar el módulo `FAISS` desde el paquete `langchain_community.vectorstores`.
#
# 2. **Confirmación de la Importación**:
#    - Una vez que se ha importado exitosamente, se imprime un mensaje `"OK: FAISS importado"` para indicar que esta operación fue completada satisfactoriamente.
#
# ## Consideraciones Adicionales
#
# - **Manejo de Errores**:
#   - En este código, no se incluye ningún bloque `try-except` para manejar posibles errores durante la importación. Si `FAISS` no está instalado o hay algún problema con su carga, el script terminará con un error inesperado sin imprimir el mensaje de confirmación.
#
# - **Dependencias**:
#   - Este código asume que `langchain_community` y `FAISS` están correctamente instalados en el entorno Python donde se ejecuta. Si no es así, se producirá un error de importación.
#
# - **Contexto**:
#   - El propósito del código depende del resto del programa. Después de esta línea, probablemente se utilizarán funciones o clases proporcionadas por `FAISS` para realizar tareas específicas relacionadas con la gestión y búsqueda de datos vectoriales.
#
# ## Conclusión
#
# Este código realiza una acción fundamental en el desarrollo de software: **importar** un módulo (`FAISS`) y **confirmar** que se ha importado correctamente. Esto es útil para asegurar que todas las dependencias necesarias estén disponibles antes de continuar con la ejecución del programa, proporcionando una retroalimentación clara sobre el éxito o fracaso de esta operación inicial.
# ```

# %%
import sys
# !{sys.executable} -m pip install -U pypdf

# %%
import pypdf
print("pypdf OK")

# %%
import sys
# !{sys.executable} -m pip install -U plotly ipywidgets

# %%
import plotly, ipywidgets
print(plotly.__version__)
print(ipywidgets.__version__)

# %%
import plotly.io as pio
pio.renderers.default = "iframe"  # el más robusto en entornos remotos / proxies

# %%
/jarvis refactoriza este codigo

import plotly.graph_objects as go
fig = go.Figure(go.Scatter(x=[1,2,3], y=[1,4,9], mode="markers"))
fig.show()
# Out:
# ```markdown
# # Refactorización del Código Proporcionado
#
# ## Código Original
#
# ```python
# import plotly.graph_objects as go
# fig = go.Figure(go.Scatter(x=[1,2,3], y=[1,4,9], mode="markers"))
# fig.show()
# ```
#
# ## Explicación del Código Original
#
# - **Importación de Plotly**: Se importa el módulo `graph_objects` de la biblioteca `plotly`, que se utiliza para crear gráficos interactivos.
# - **Creación de un Gráfico de Dispersión**: Se crea una figura (`fig`) con un objeto `Scatter` que representa un gráfico de dispersión. Los datos utilizados son simples puntos en el plano cartesiano: `(1, 1)`, `(2, 4)` y `(3, 9)`.
# - **Mostrar el Gráfico**: Se utiliza el método `show()` para renderizar y mostrar el gráfico.
#
# ## Código Refactorizado
#
# ```python
# import plotly.graph_objects as go
#
# # Crear una figura con un gráfico de dispersión
# fig = go.Figure(
#     data=go.Scatter(
#         x=[1, 2, 3],
#         y=[1, 4, 9],
#         mode="markers"
#     )
# )
#
# # Mostrar el gráfico
# fig.show()
# ```
#
# ## Explicación del Código Refactorizado
#
# ### 1. **Separación en Líneas para Mejor Legibilidad**
#
# ```python
# fig = go.Figure(
#     data=go.Scatter(
#         x=[1, 2, 3],
#         y=[1, 4, 9],
#         mode="markers"
#     )
# )
# ```
#
# - **Ventajas**:
#   - La estructura de código es más clara y fácil de leer.
#   - Cada parámetro se coloca en una línea separada, lo que facilita la identificación y el mantenimiento del código.
#
# ### 2. **Uso de Parámetros Nombrados (`data`)**
#
# ```python
# fig = go.Figure(
#     data=go.Scatter(
#         x=[1, 2, 3],
#         y=[1, 4, 9],
#         mode="markers"
#     )
# )
# ```
#
# - **Ventajas**:
#   - Al especificar `data=` explícitamente, el código se vuelve más legible.
#   - Esto es especialmente útil cuando se utilizan múltiples trazas o objetos gráficos en una sola figura.
#
# ### 3. **Mantenimiento y Escalabilidad**
#
# - La refactorización facilita la adición de nuevas trazas o elementos al gráfico si es necesario. Por ejemplo, agregar otra línea podría verse así:
#
# ```python
# fig.add_trace(go.Scatter(x=[1, 2, 3], y=[2, 5, 8], mode="lines"))
# ```
#
# ## Conclusión
#
# La refactorización del código no solo mejora la legibilidad sino que también facilita el mantenimiento y la escalabilidad. Este enfoque permite a otros desarrolladores comprender rápidamente qué está haciendo el código y cómo puede ser modificado en el futuro.
#
# ```

# %%
from pathlib import Path

DB_DIR = Path("/giova/llms-engineering-main/vector_db")
print("DB_DIR exists:", DB_DIR.exists())
print("Contents:")
if DB_DIR.exists():
    for p in DB_DIR.rglob("*"):
        print(" -", p)

# %%
import sqlite3
from pathlib import Path

db_file = Path("/giova/llms-engineering-main/vector_db/chroma.sqlite3")
print("DB exists:", db_file.exists(), "size:", db_file.stat().st_size)

con = sqlite3.connect(str(db_file))
cur = con.cursor()
cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
tables = [r[0] for r in cur.fetchall()]
con.close()

print("Tables:", tables)
print("Has collections table?", "collections" in tables)

# %%
# 2) Solución “a prueba de balas”: borrar y recrear (bien)
import shutil
from pathlib import Path
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

DB_DIR = Path("/giova/llms-engineering-main/vector_db")
COLLECTION_NAME = "private_kb"

# 1) Cierra referencias viejas por si acaso
try:
    del vectorstore
except NameError:
    pass

# 2) Borra TODO el directorio (no solo el archivo)
shutil.rmtree(DB_DIR, ignore_errors=True)
DB_DIR.mkdir(parents=True, exist_ok=True)

# 3) Crea desde cero
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=str(DB_DIR),
    collection_name=COLLECTION_NAME,
)

print("✅ Rebuild OK. Count:", vectorstore._collection.count())

# %%
# %pip install scikit-learn

# %%
# %pip install -U gensim

# %%
# %pip install -U gensim

# %%
# %pip install -U anthropic

# %%
/jarvis crea una funcion que genere el codigo fibonacci
# Out:
# ```markdown
# # Función para generar la secuencia Fibonacci en Python
#
# ```python
# def fibonacci(n):
#     fib_sequence = []
#     a, b = 0, 1
#     while len(fib_sequence) < n:
#         fib_sequence.append(a)
#         a, b = b, a + b
#     return fib_sequence
#
# # Ejemplo de uso
# n = 10
# print(f"Los primeros {n} números de Fibonacci son: {fibonacci(n)}")
# ```
#
# Esta función `fibonacci` toma un entero `n` como argumento y devuelve una lista que contiene los primeros `n` números de la secuencia de Fibonacci. Los dos primeros números de Fibonacci son 0 y 1, y cada número posterior en la secuencia es la suma de los dos anteriores.
# ```

# %%
jarvis
# Out:
#         <style>
#           /* Chips: fondo transparente, texto del tema, separador sutil */
#           .jv-chip button.widget-button {
#             background: transparent !important;
#             border-top: none !important;
#             border-left: none !important;
#             border-right: none !important;
#             border-bottom: 1px solid var(--jp-border-color2, rgba(128,128,128,0.2)) !important;
#             border-radius: 0 !important;
#             text-align: left !important;
#             padding-left: 14px !important;
#             font-size: 13px !important;
#             width: 100% !important;
#           }
#           .jv-chip button.widget-button:hover {
#             background: var(--jp-layout-color2, rgba(128,128,128,0.1)) !important;
#           }
#           /* Contenedor chips: borde sutil del tema, sin bg hardcodeado */
#           .jv-cmd-box {
#             border: 1px solid var(--jp-border-color1, rgba(128,128,128,0.3)) !important;
#             border-radius: 6px !important;
#             overflow: hidden !important;
#             margin-top: 4px !important;
#           }
#           /* Panel principal: borde brand, sin bg hardcodeado */
#           .jv-panel {
#             border: 1px solid var(--jp-brand-color2, #4a90e2) !important;
#             border-radius: 8px !important;
#             padding: 8px 10px !important;
#             max-width: 900px !important;
#           }
#         </style>
# VBox(children=(HBox(children=(HTML(value='<div style="line-height:0;flex-shrink:0">\n<svg xmlns="http://www.w3…
