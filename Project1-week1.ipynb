# %% [markdown]
# # Project 1: Personalized Programming Tutor
#
# ## Executive Summary
#
# This project demonstrates the creation of an **AI-powered educational tool** designed to explain complex programming concepts in a personalized, easy-to-understand manner.
#
# By leveraging Large Language Models (LLMs), this application acts as a virtual tutor that:
# 1.  **Analyzes** raw code snippets provided by the user.
# 2.  **Deconstructs** the logic into step-by-step explanations.
# 3.  **Teaches** the underlying concepts and best practices.
# 4.  **Delivers** content using real-time streaming for an engaging user experience.
#
# **Key Engineering Concepts:**
# - **LLM Integration**: Seamless switching between OpenAI (Cloud) and Ollama (Local) providers.
# - **Prompt Engineering**: Designing robust system prompts to enforce a specific teaching persona.
# - **Streaming Responses**: Implementing token-by-token rendering for low-latency feedback.
# - **Interactive UI**: Building a command-line interface (CLI) for user interaction.

# %% [markdown]
# ## 1. Environment Setup & Imports
#
# We begin by importing the necessary libraries.
# - `os` and `dotenv`: For secure management of API keys and configuration via environment variables.
# - `IPython.display`: To render Markdown and handle real-time display updates in the notebook.
# - `openai`: The standard client library used to interact with both OpenAI's API and Ollama's OpenAI-compatible endpoint.

# %%
# %run ./config/llm_settings.py

# %%
# %run ./utils/llm_functions.py

# %% [markdown]
# ## 3. Client Initialization
#
# Here we initialize the API client based on the selected provider.
#
# - **Ollama**: Connects to a local server (usually `localhost:11434`). It mimics the OpenAI API structure, allowing us to use the same client code.
# - **OpenAI**: Connects to the official API using your secret key.
#
# This abstraction layer allows the rest of the application to remain unchanged regardless of the underlying model.

# %% [markdown]
# ## 4. The Inference Engine
#
# This function, `callModel`, is the core of our application. It handles the communication with the LLM.
#
# **Key Feature: Streaming**
# When `use_stream=True`, the function yields chunks of text as they are generated. We use `IPython.display.update_display` to append these chunks to the screen in real-time, creating a "typewriter" effect. This significantly improves perceived performance, as the user doesn't have to wait for the entire explanation to be generated.

# %%
from IPython.display import display, Markdown


def call_model(
    client,
    model,
    messages,
    use_stream=False,
    temperature=None,
    max_tokens=None,
    **kwargs,
):
    """
    Ejecuta una llamada contra Ollama, NVIDIA NIM u otro cliente
    compatible con OpenAI.

    Si temperature o max_tokens son None, no se envían al proveedor
    y se utilizan sus valores predeterminados.
    """

    request_params = {
        "model": model,
        "messages": messages,
        "stream": use_stream,
        **kwargs,
    }

    if temperature is not None:
        request_params["temperature"] = temperature

    if max_tokens is not None:
        request_params["max_tokens"] = max_tokens

    completion = client.chat.completions.create(**request_params)

    if use_stream:
        response_text = ""
        display_handle = None

        for chunk in completion:
            if not getattr(chunk, "choices", None):
                continue

            delta = chunk.choices[0].delta
            content = getattr(delta, "content", None) or ""

            if not content:
                continue

            response_text += content

            if display_handle is None:
                display_handle = display(
                    Markdown(response_text),
                    display_id=True,
                )
            else:
                display_handle.update(
                    Markdown(response_text)
                )

        return response_text

    result = completion.choices[0].message.content or ""
    display(Markdown(result))

    return result

# %%
def callModelOllama(
    messages,
    use_stream=False,
    model=None,
    temperature=None,
    max_tokens=None,
    **kwargs,
):
    return call_model(
        client=ollama_client,
        model=model or OLLAMA_MODEL_LLAMA,
        messages=messages,
        use_stream=use_stream,
        temperature=temperature,
        max_tokens=max_tokens,
        **kwargs,
    )

# %%
def callModelNvidia(
    messages,
    use_stream=False,
    model=None,
    temperature=None,
    max_tokens=None,
    **kwargs,
):
    return call_model(
        client=nvidia_client,
        model=model or NVIDIA_MODEL,
        messages=messages,
        use_stream=use_stream,
        temperature=temperature,
        max_tokens=max_tokens,
        **kwargs,
    )

# %% [markdown]
# ## 5. Persona Design (System Prompt)
#
# The **System Prompt** is where we define the AI's behavior. For this project, we are crafting a "Personalized Tutor" persona.
#
# We explicitly instruct the model to:
# - Avoid overly technical jargon without explanation.
# - Use analogies to make abstract concepts concrete.
# - Focus on the "why" and "how", not just the syntax.
# - Format the output cleanly with Markdown.

# %%
system_prompt = """
You are an expert programming tutor with deep knowledge in Python, JavaScript, and software engineering.

Your teaching style:
- Explain concepts clearly and step by step.
- Use analogies and real-world examples to make concepts stick.
- Break down complex code into understandable parts.
- Highlight best practices and common pitfalls.
- Encourage learning by explaining the "why" behind the code.

Response format:
- Always respond in well-formatted Markdown.
- Use headers, lists, and code blocks appropriately.
- Do NOT wrap your entire response in markdown code fences (```).
- Be concise but thorough.
"""

# %% [markdown]
# ## 6. User Interaction
#
# We create a simple interactive prompt to accept code snippets from the user. This simulates a real-world scenario where a student asks for help with a specific block of code.

# %%
print("=" * 60)
print("🎓 PERSONALIZED PROGRAMMING TUTOR")
print("=" * 60)
print("\nEnter the code you want to understand.")
print("\nExample:")
print('  yield from {book.get("author") for book in books if book.get("author")}')
print("")
print("-" * 60)
#question = ininput()
question = '''
\ncallModelNvidia(
    \nmessages,
    \nuse_stream=True,
    \ntemperature=0.2,
    \nmax_tokens=2048,
\n)
'''
# Out:
# ============================================================
# 🎓 PERSONALIZED PROGRAMMING TUTOR
# ============================================================
#
# Enter the code you want to understand.
#
# Example:
#   yield from {book.get("author") for book in books if book.get("author")}
#
# ------------------------------------------------------------

# %% [markdown]
# ## 7. Prompt Engineering
#
# We wrap the user's raw input into a structured prompt. This technique ensures the model knows exactly *what* to do with the code (explain it) rather than just executing it or refactoring it.
#
# We specifically ask for:
# 1. Functionality summary.
# 2. Step-by-step breakdown.
# 3. Use cases.
# 4. Key concepts.

# %%
user_prompt = f"""
Please explain the following code in detail:

```python
{question}
```

Include:
1. What this code does
2. How it works step by step
3. Why someone would use this approach
4. Any important concepts or patterns involved
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %% [markdown]
# ## 8. execution without parameters
#
# Finally, we call the model with our constructed messages and enable streaming to see the tutor in action.

# %%
callModelOllama(
    messages,
    use_stream=True,
)
# Out:
# **Call to the `callModelNvidia` Function**
# ===========================================
#
# ### 1. What this code does
#
# This code calls a function named `callModelNvidia`, passing in several parameters, including an object called `messages`. The purpose of calling this function is likely to generate text responses or perform other modeling tasks using the Nvidia model.
#
# ### 2. How it works step by step
#
# Let's break down what happens when you run this code:
#
# #### a. `callModelNvidia` Function Definition (assumed elsewhere in the codebase)
#
# The `callModelNvidia` function is not defined within this snippet, but we can assume that it has been implemented elsewhere in the codebase. This function takes in several parameters required for the Nvidia model to perform its tasks.
#
# #### b. `messages` Parameter
#
# The first parameter passed to `callModelNvidia` is an object called `messages`. We don't know what specific data this object contains without more context, but it likely holds input text or some other form of data for the model to process.
#
# #### c. Parameters for Model Configuration (`use_stream=True`, `temperature=0.2`, `max_tokens=2048`)
#
# The remaining parameters configure the Nvidia model:
#
# *   `use_stream`: A boolean parameter that enables a streaming approach, which allows for incremental processing or handling of large inputs.
# *   `temperature`: Controls the creativity and variability in generated text. Set to 0.2 by default, this suggests the author wants more human-like responses with some level of risk-taking allowed for new ideas.
#
# !!! Note: Higher temperature value may increase the likelihood of generating nonsensical content.
#
# *   `max_tokens`: Defines the maximum number of tokens (small units of input or output data) the model can process. With 2048, you're allowing this model to generate up to a specific word count in its responses.
#
# ### 3. Why someone would use this approach
#
# This approach is beneficial for several reasons:
#
# *   **Efficient processing:** The `use_stream=True` parameter enables efficient processing of large inputs or text generation tasks.
# *   **Balancing creativity and reliability:** By setting the temperature to 0.2, you strike a balance between maintaining a somewhat reliable output and still exploring innovative ideas that are likely.
#
# !!! However, this comes with potential pitfalls.
#
# ### 4. Any important concepts or patterns involved
#
# Important concepts in this code include:
#
# *   **Model architecture**: Although not explicitly stated here, `callModelNvidia` likely builds upon the Nvidia transformer architectures, like BERT (Bidirectional Encoder Representations from Transformers) in its base implementation.
# *   **Configuring model behavior**: Various parameters passed to `callModelNvidia`, such as `use_stream=True`, control the underlying processing and generation behaviors.
#
# !!! Remember: Properly configuring these parameters can significantly influence the output quality of models like this.
# "**Call to the `callModelNvidia` Function**\n===========================================\n\n### 1. What this code does\n\nThis code calls a function named `callModelNvidia`, passing in several parameters, including an object called `messages`. The purpose of calling this function is likely to generate text responses or perform other modeling tasks using the Nvidia model.\n\n### 2. How it works step by step\n\nLet's break down what happens when you run this code:\n\n#### a. `callModelNvidia` Function Definition (assumed elsewhere in the codebase)\n\nThe `callModelNvidia` function is not defined within this snippet, but we can assume that it has been implemented elsewhere in the codebase. This function takes in several parameters required for the Nvidia model to perform its tasks.\n\n#### b. `messages` Parameter\n\nThe first parameter passed to `callModelNvidia` is an object called `messages`. We don't know what specific data this object contains without more context, but it likely holds input text or some other form of data for the model to process.\n\n#### c. Parameters for Model Configuration (`use_stream=True`, `temperature=0.2`, `max_tokens=2048`)\n\nThe remaining parameters configure the Nvidia model:\n\n*   `use_stream`: A boolean parameter that enables a streaming approach, which allows for incremental processing or handling of large inputs.\n*   `temperature`: Controls the creativity and variability in generated text. Set to 0.2 by default, this suggests the author wants more human-like responses with some level of risk-taking allowed for new ideas.\n\n!!! Note: Higher temperature value may increase the likelihood of generating nonsensical content.\n\n*   `max_tokens`: Defines the maximum number of tokens (small units of input or output data) the model can process. With 2048, you're allowing this model to generate up to a specific word count in its responses.\n\n### 3. Why someone would use this approach\n\nThis approach is beneficial for several reasons:\n\n*   **Efficient processing:** The `use_stream=True` parameter enables efficient processing of large inputs or text generation tasks.\n*   **Balancing creativity and reliability:** By setting the temperature to 0.2, you strike a balance between maintaining a somewhat reliable output and still exploring innovative ideas that are likely.\n\n!!! However, this comes with potential pitfalls.\n\n### 4. Any important concepts or patterns involved\n\nImportant concepts in this code include:\n\n*   **Model architecture**: Although not explicitly stated here, `callModelNvidia` likely builds upon the Nvidia transformer architectures, like BERT (Bidirectional Encoder Representations from Transformers) in its base implementation.\n*   **Configuring model behavior**: Various parameters passed to `callModelNvidia`, such as `use_stream=True`, control the underlying processing and generation behaviors.\n\n!!! Remember: Properly configuring these parameters can significantly influence the output quality of models like this."

# %%
callModelNvidia(
    messages,
    use_stream=True
)
# Out:
# Here is a detailed breakdown of the code snippet you provided.
#
# ## 1. What This Code Does
#
# This code invokes a function named `callModelNvidia` with a specific set of parameters. Based on the naming conventions and arguments, this function acts as a bridge to communicate with an NVIDIA-hosted Large Language Model (LLM)—such as Llama 3, Mistral, or Gemma—via an API.
#
# It is sending a conversation (`messages`) to the model and asking it to generate a response with specific behavior: streaming the output, using a low randomness setting, and limiting the length of the answer.
#
# ## 2. How It Works Step by Step
#
# Let's break down exactly what each argument is doing when this function runs:
#
# *   **`messages`**: This is the first argument passed. It represents the conversation history. It is typically a list of dictionaries formatted like `[{"role": "user", "content": "Hello!"}]`. The function will send this to the NVIDIA API so the model knows what the user is asking.
# *   **`use_stream=True`**: This tells the API to enable **streaming**. Instead of waiting for the AI to generate the entire 2,048 tokens and *then* sending them back all at once, the API will send the text back in small chunks (often word-by-word or token-by-token) as it is being generated.
# *   **`temperature=0.2`**: Temperature controls the "creativity" or randomness of the model's response.
#     *   `0.0` is completely deterministic (it always picks the most likely next word).
#     *   `1.0` is highly creative and unpredictable.
#     *   By setting it to `0.2`, the developer is asking the model to be highly focused, factual, and logical. This is ideal for coding tasks, factual Q&A, or data extraction.
# *   **`max_tokens=2048`**: This places a strict limit on the maximum length of the model's response. A "token" is roughly 3/4 of a word. So, 2,048 tokens allows the model to generate about 1,500 words before it is forced to stop.
#
# ## 3. Why Someone Would Use This Approach
#
# A developer would use this specific combination of parameters to create a highly responsive, predictable, and cost-effective user experience.
#
# *   **Why use `use_stream=True`?** User experience. If a model takes 10 seconds to generate a 2,000-word answer, a user staring at a loading spinner will think the app is broken. Streaming allows the user to see the text appearing in real-time, much like typing in a chat window. It makes the app feel incredibly fast.
# *   **Why use `temperature=0.2`?** Consistency. If a developer is building a tool that writes Python code or summarizes legal documents, they do not want the AI to "get creative" or make things up (hallucinate). A low temperature keeps the model strictly focused on the most probable, logical output.
# *   **Why set `max_tokens=2048`?** Resource management. API calls are often billed by the token. Without a limit, a model might accidentally generate an endless rambling response, costing the developer money and slowing down the app. 2048 is a safe, generous limit for a detailed response without spiraling out of control.
#
# ## 4. Important Concepts and Patterns Involved
#
# Understanding this code requires familiarity with a few core software engineering and AI concepts:
#
# *   **Keyword Arguments (Kwargs):** In Python, you can pass arguments by position, or by keyword. Here, `use_stream`, `temperature`, and `max_tokens` are passed as keyword arguments. This is a strong Python best practice because it makes the code self-documenting. You don't have to guess what `True` or `0.2` represent; their names tell you exactly what they do.
# *   **The Chat Completions API Pattern:** This code follows the emerging industry standard for interacting with LLMs (popularized by OpenAI and adopted by NVIDIA, Anthropic, and others). The standard pattern involves passing a list of `messages` and adjusting generation parameters like `temperature` and `max_tokens`.
# *   **Streaming / Server-Sent Events (SSE):** When `use_stream=True` is enabled, the underlying HTTP request likely expects an SSE connection. Instead of a standard HTTP request that closes when the full payload is ready, the connection stays open, and the server "pushes" chunks of data to the client until the stream finishes.
# *   **Abstraction:** The code snippet shows a custom function (`callModelNvidia`). A developer wrote this wrapper function to hide the messy, boilerplate HTTP request code required to talk to NVIDIA's servers. This is a common software engineering pattern: **Abstraction**. It allows the rest of the codebase to call AI models simply without needing to know how the API keys or HTTP headers are structured behind the scenes.
# 'Here is a detailed breakdown of the code snippet you provided.\n\n## 1. What This Code Does\n\nThis code invokes a function named `callModelNvidia` with a specific set of parameters. Based on the naming conventions and arguments, this function acts as a bridge to communicate with an NVIDIA-hosted Large Language Model (LLM)—such as Llama 3, Mistral, or Gemma—via an API. \n\nIt is sending a conversation (`messages`) to the model and asking it to generate a response with specific behavior: streaming the output, using a low randomness setting, and limiting the length of the answer.\n\n## 2. How It Works Step by Step\n\nLet\'s break down exactly what each argument is doing when this function runs:\n\n*   **`messages`**: This is the first argument passed. It represents the conversation history. It is typically a list of dictionaries formatted like `[{"role": "user", "content": "Hello!"}]`. The function will send this to the NVIDIA API so the model knows what the user is asking.\n*   **`use_stream=True`**: This tells the API to enable **streaming**. Instead of waiting for the AI to generate the entire 2,048 tokens and *then* sending them back all at once, the API will send the text back in small chunks (often word-by-word or token-by-token) as it is being generated.\n*   **`temperature=0.2`**: Temperature controls the "creativity" or randomness of the model\'s response. \n    *   `0.0` is completely deterministic (it always picks the most likely next word).\n    *   `1.0` is highly creative and unpredictable.\n    *   By setting it to `0.2`, the developer is asking the model to be highly focused, factual, and logical. This is ideal for coding tasks, factual Q&A, or data extraction.\n*   **`max_tokens=2048`**: This places a strict limit on the maximum length of the model\'s response. A "token" is roughly 3/4 of a word. So, 2,048 tokens allows the model to generate about 1,500 words before it is forced to stop.\n\n## 3. Why Someone Would Use This Approach\n\nA developer would use this specific combination of parameters to create a highly responsive, predictable, and cost-effective user experience.\n\n*   **Why use `use_stream=True`?** User experience. If a model takes 10 seconds to generate a 2,000-word answer, a user staring at a loading spinner will think the app is broken. Streaming allows the user to see the text appearing in real-time, much like typing in a chat window. It makes the app feel incredibly fast.\n*   **Why use `temperature=0.2`?** Consistency. If a developer is building a tool that writes Python code or summarizes legal documents, they do not want the AI to "get creative" or make things up (hallucinate). A low temperature keeps the model strictly focused on the most probable, logical output.\n*   **Why set `max_tokens=2048`?** Resource management. API calls are often billed by the token. Without a limit, a model might accidentally generate an endless rambling response, costing the developer money and slowing down the app. 2048 is a safe, generous limit for a detailed response without spiraling out of control.\n\n## 4. Important Concepts and Patterns Involved\n\nUnderstanding this code requires familiarity with a few core software engineering and AI concepts:\n\n*   **Keyword Arguments (Kwargs):** In Python, you can pass arguments by position, or by keyword. Here, `use_stream`, `temperature`, and `max_tokens` are passed as keyword arguments. This is a strong Python best practice because it makes the code self-documenting. You don\'t have to guess what `True` or `0.2` represent; their names tell you exactly what they do.\n*   **The Chat Completions API Pattern:** This code follows the emerging industry standard for interacting with LLMs (popularized by OpenAI and adopted by NVIDIA, Anthropic, and others). The standard pattern involves passing a list of `messages` and adjusting generation parameters like `temperature` and `max_tokens`.\n*   **Streaming / Server-Sent Events (SSE):** When `use_stream=True` is enabled, the ...

# %% [markdown]
# ## 8. execution with parameters
#
# Finally, we call the model with our constructed messages and enable streaming to see the tutor in action.

# %%
callModelNvidia(
    messages,
    use_stream=True,
    temperature=0.2,
    max_tokens=2048,
)
# Out:
# Here is a detailed breakdown of the code snippet you provided.
#
# ## 1. What This Code Does
#
# This code is a function call to an AI model hosted on NVIDIA's infrastructure (likely via the NVIDIA NIM API or NVIDIA's AI Enterprise platform).
#
# Specifically, it is sending a conversation history (`messages`) to a Large Language Model (LLM) and asking it to generate a response. By looking at the parameters, it is instructing the model to generate text in real-time as it is being created (`use_stream=True`), to be highly focused and deterministic (`temperature=0.2`), and to limit its answer to a maximum length (`max_tokens=2048`).
#
# ## 2. How It Works Step by Step
#
# Let's break down the components of this function call:
#
# ### The Function Name: `callModelNvidia(...)`
# This is a custom function. It is not a built-in Python function, meaning the developer wrote this wrapper themselves (or imported it from an internal library). Its job is to handle the HTTP request and authentication required to talk to NVIDIA's API endpoints.
#
# ### The Arguments:
# *   **`messages`**: This is the first argument passed. It is typically a list of dictionaries representing the conversation history. For example:
#     ```python
#     messages = [
#         {"role": "user", "content": "Explain quantum computing in simple terms."}
#     ]
#     ```
# *   **`use_stream=True`**: This tells the API to use Server-Sent Events (SSE) or chunked transfer encoding. Instead of waiting for the AI to finish generating the entire 2048 tokens (which could take 10-20 seconds), the server will send the text back word-by-word as soon as it is generated.
# *   **`temperature=0.2`**: Temperature controls the randomness of the AI's predictions. The scale is usually 0.0 to 1.0 (or higher).
#     *   A temperature of `1.0` makes the model highly creative and unpredictable.
#     *   A temperature of `0.2` makes the model very conservative and focused. It will likely choose the most probable next word every time. This is ideal for coding, factual answering, or data extraction.
# *   **`max_tokens=2048`**: This is a strict cutoff limit. A "token" in AI is roughly equivalent to 3/4 of a word. Setting this to 2048 means the model will stop generating text once it hits this limit, preventing runaway responses and controlling API costs.
#
# ## 3. Why Someone Would Use This Approach
#
# A developer would write and use this specific configuration for a few key reasons:
#
# *   **Improved User Experience (Streaming):** Waiting for a long AI response feels broken to a user. By using `use_stream=True`, the developer can print the text to the screen as it arrives, mimicking the typing effect seen in ChatGPT. This drastically reduces the "time to first token," making the app feel much faster.
# *   **Reliability and Consistency (Low Temperature):** If you are building an application that summarizes legal documents, writes code, or extracts structured JSON data, you do *not* want the AI to be creative. You want it to be precise. `temperature=0.2` ensures the model behaves predictably.
# *   **Cost and Resource Management (`max_tokens`):** AI APIs charge based on the number of tokens generated. By capping the output at 2048 tokens, the developer ensures a single weird prompt doesn't accidentally generate a 10,000-token essay, saving money and preventing the application from hanging.
#
# ## 4. Important Concepts and Patterns Involved
#
# ### A. The Wrapper Pattern
# `callModelNvidia` is an abstraction layer. Instead of writing raw HTTP requests with API keys, headers, and JSON payloads every time they want to talk to the AI, the developer created a helper function. This is a software engineering best practice because it separates the *business logic* (what to ask the AI) from the *infrastructure logic* (how to talk to NVIDIA).
#
# ### B. Streaming via Generators
# Under the hood, to make `use_stream=True` work in Python, the `callModelNvidia` function likely uses the `yield` keyword, making it a **generator function**.
#
# Here is a simplified analogy of how that works under the hood:
# ```python
# def callModelNvidia(messages, use_stream, temperature, max_tokens):
#     # ... setup connection to NVIDIA API ...
#
#     if use_stream:
#         # Yields chunks of text as they arrive from the server
#         for chunk in response.iter_lines():
#             yield chunk
#     else:
#         # Waits for the whole response, then returns it all at once
#         return response.json()
# ```
# Because it uses `yield`, the calling code can loop through the function like this: `for text_chunk in callModelNvidia(...): print(text_chunk)`.
#
# ### C. The Chat Completions Standard
# The fact that the first argument is simply named `messages` strongly suggests this function is adhering to the OpenAI Chat Completions API standard. NVIDIA (and most other AI providers like Anthropic, Google, and Mistral) have adopted OpenAI's API format as the industry standard. This means a developer can swap `callModelNvidia` for `callModelOpenAI` later without changing the format of their `messages` variable.
# 'Here is a detailed breakdown of the code snippet you provided.\n\n## 1. What This Code Does\n\nThis code is a function call to an AI model hosted on NVIDIA\'s infrastructure (likely via the NVIDIA NIM API or NVIDIA\'s AI Enterprise platform). \n\nSpecifically, it is sending a conversation history (`messages`) to a Large Language Model (LLM) and asking it to generate a response. By looking at the parameters, it is instructing the model to generate text in real-time as it is being created (`use_stream=True`), to be highly focused and deterministic (`temperature=0.2`), and to limit its answer to a maximum length (`max_tokens=2048`).\n\n## 2. How It Works Step by Step\n\nLet\'s break down the components of this function call:\n\n### The Function Name: `callModelNvidia(...)`\nThis is a custom function. It is not a built-in Python function, meaning the developer wrote this wrapper themselves (or imported it from an internal library). Its job is to handle the HTTP request and authentication required to talk to NVIDIA\'s API endpoints.\n\n### The Arguments:\n*   **`messages`**: This is the first argument passed. It is typically a list of dictionaries representing the conversation history. For example:\n    ```python\n    messages = [\n        {"role": "user", "content": "Explain quantum computing in simple terms."}\n    ]\n    ```\n*   **`use_stream=True`**: This tells the API to use Server-Sent Events (SSE) or chunked transfer encoding. Instead of waiting for the AI to finish generating the entire 2048 tokens (which could take 10-20 seconds), the server will send the text back word-by-word as soon as it is generated.\n*   **`temperature=0.2`**: Temperature controls the randomness of the AI\'s predictions. The scale is usually 0.0 to 1.0 (or higher). \n    *   A temperature of `1.0` makes the model highly creative and unpredictable. \n    *   A temperature of `0.2` makes the model very conservative and focused. It will likely choose the most probable next word every time. This is ideal for coding, factual answering, or data extraction.\n*   **`max_tokens=2048`**: This is a strict cutoff limit. A "token" in AI is roughly equivalent to 3/4 of a word. Setting this to 2048 means the model will stop generating text once it hits this limit, preventing runaway responses and controlling API costs.\n\n## 3. Why Someone Would Use This Approach\n\nA developer would write and use this specific configuration for a few key reasons:\n\n*   **Improved User Experience (Streaming):** Waiting for a long AI response feels broken to a user. By using `use_stream=True`, the developer can print the text to the screen as it arrives, mimicking the typing effect seen in ChatGPT. This drastically reduces the "time to first token," making the app feel much faster.\n*   **Reliability and Consistency (Low Temperature):** If you are building an application that summarizes legal documents, writes code, or extracts structured JSON data, you do *not* want the AI to be creative. You want it to be precise. `temperature=0.2` ensures the model behaves predictably.\n*   **Cost and Resource Management (`max_tokens`):** AI APIs charge based on the number of tokens generated. By capping the output at 2048 tokens, the developer ensures a single weird prompt doesn\'t accidentally generate a 10,000-token essay, saving money and preventing the application from hanging.\n\n## 4. Important Concepts and Patterns Involved\n\n### A. The Wrapper Pattern\n`callModelNvidia` is an abstraction layer. Instead of writing raw HTTP requests with API keys, headers, and JSON payloads every time they want to talk to the AI, the developer created a helper function. This is a software engineering best practice because it separates the *business logic* (what to ask the AI) from the *infrastructure logic* (how to talk to NVIDIA).\n\n### B. Streaming via Generators\nUnder the hood, to make `use_stream=True` work in Python, the `callModelNvidia` function likely uses the `yield` keyword, making it a **g ...

# %%
callModelNvidia(
    messages,
    temperature=0.7,
    max_tokens=4096,
    top_p=0.9,
    seed=42,
)
# Out:
# Here is a detailed breakdown of the code you provided.
#
# ## 1. What This Code Does
#
# This code snippet is a **function call** in Python. It is sending a request to an AI model hosted by NVIDIA (likely through NVIDIA's NIM API or their integration with platforms like OpenAI's API standard).
#
# Specifically, it is asking the AI model to generate a response based on a provided chat history (`messages`), and it is configuring the AI to type out its answer word-by-word in real-time (`use_stream=True`), while keeping the creativity of the response relatively low and strictly controlled (`temperature=0.2`).
#
# ---
#
# ## 2. How It Works Step by Step
#
# Let's break down the arguments being passed into the `callModelNvidia` function:
#
# ### `messages`
# This is the core payload. In modern AI APIs, `messages` is usually a list of dictionaries representing the conversation history.
# *Example:* `[{"role": "user", "content": "Hello!"}]`. The AI reads this to understand the context of what it needs to respond to.
#
# ### `use_stream=True`
# **Streaming** is turned on.
# * **Without streaming:** The AI generates the entire response on the server, and your code waits in silence until the whole answer is finished. Only then does it return the text.
# * **With streaming:** The server sends the text back in tiny chunks (tokens) as soon as they are generated. Your application can display these chunks immediately, giving the user a typewriter effect.
#
# ### `temperature=0.2`
# Temperature controls the "creativity" or randomness of the AI.
# * The scale usually goes from `0.0` to `1.0` (sometimes up to `2.0`).
# * A value of `0.2` is very **low**. This tells the model to play it safe, stick to the most probable words, and be highly deterministic. This is perfect for technical tasks, coding, or factual Q&A where you don't want the AI to hallucinate or get creative.
#
# ### `max_tokens=2048`
# This sets a hard limit on how long the AI's response can be.
# * In AI terminology, a "token" is roughly 3/4 of a word.
# * Setting this to `2048` means the AI will stop generating text after about 1,500 words. This prevents the model from rambling indefinitely and helps control API costs (since you usually pay per token generated).
#
# ---
#
# ## 3. Why Someone Would Use This Approach
#
# A developer would use this exact configuration when they need **fast, reliable, and controlled factual responses**.
#
# * **Why streaming?** User experience. If a user asks a complex question, waiting 10 seconds for a 2048-token response feels broken. Streaming the text makes the application feel incredibly fast and responsive, even if the total generation time is the same.
# * **Why low temperature?** If you are building a tool that writes code, summarizes legal documents, or extracts data, you want strict adherence to facts. A temperature of `0.2` heavily reduces the chance of the AI making things up.
# * **Why a high token limit?** The developer wants to ensure the AI has enough room to give a thorough answer without getting cut off prematurely, but `2048` is a safe ceiling to prevent runaway costs.
#
# ---
#
# ## 4. Important Concepts and Patterns Involved
#
# ### The Chat Completions API Pattern
# The use of a `messages` array is the industry standard (pioneered by OpenAI and adopted by NVIDIA, Anthropic, and others). Instead of sending a single string of text, you send a structured conversation. This allows the AI to understand "who said what" (System, User, Assistant).
#
# ### Server-Sent Events (SSE) for Streaming
# Under the hood, when `use_stream=True` is passed, the HTTP request to the NVIDIA server stays open. The server pushes data to the client in chunks using a protocol called Server-Sent Events. The Python code likely uses a loop (like `for chunk in response:`) to catch these pieces as they arrive.
#
# ### Deterministic Inference
# By setting `temperature=0.2`, the developer is leaning into **determinism**—the idea that feeding the same input should yield nearly the same output every time. This is crucial for automated pipelines where AI output needs to be predictable and testable.
#
# ### Common Pitfall to Watch Out For
# If you are writing the implementation for this function, remember that **streaming responses cannot be handled like normal strings**.
# You cannot do this:
# ```python
# # BAD: Will cause an error or print a memory address
# response = callModelNvidia(messages, use_stream=True, temperature=0.2, max_tokens=2048)
# print(response)
# ```
# Instead, you must iterate over the stream:
# ```python
# # GOOD: Handles the stream correctly
# response_stream = callModelNvidia(messages, use_stream=True, temperature=0.2, max_tokens=2048)
#
# for chunk in response_stream:
#     print(chunk.choices[0].delta.content, end="")
# ```
# 'Here is a detailed breakdown of the code you provided.\n\n## 1. What This Code Does\n\nThis code snippet is a **function call** in Python. It is sending a request to an AI model hosted by NVIDIA (likely through NVIDIA\'s NIM API or their integration with platforms like OpenAI\'s API standard). \n\nSpecifically, it is asking the AI model to generate a response based on a provided chat history (`messages`), and it is configuring the AI to type out its answer word-by-word in real-time (`use_stream=True`), while keeping the creativity of the response relatively low and strictly controlled (`temperature=0.2`).\n\n---\n\n## 2. How It Works Step by Step\n\nLet\'s break down the arguments being passed into the `callModelNvidia` function:\n\n### `messages`\nThis is the core payload. In modern AI APIs, `messages` is usually a list of dictionaries representing the conversation history. \n*Example:* `[{"role": "user", "content": "Hello!"}]`. The AI reads this to understand the context of what it needs to respond to.\n\n### `use_stream=True`\n**Streaming** is turned on. \n* **Without streaming:** The AI generates the entire response on the server, and your code waits in silence until the whole answer is finished. Only then does it return the text.\n* **With streaming:** The server sends the text back in tiny chunks (tokens) as soon as they are generated. Your application can display these chunks immediately, giving the user a typewriter effect. \n\n### `temperature=0.2`\nTemperature controls the "creativity" or randomness of the AI. \n* The scale usually goes from `0.0` to `1.0` (sometimes up to `2.0`). \n* A value of `0.2` is very **low**. This tells the model to play it safe, stick to the most probable words, and be highly deterministic. This is perfect for technical tasks, coding, or factual Q&A where you don\'t want the AI to hallucinate or get creative.\n\n### `max_tokens=2048`\nThis sets a hard limit on how long the AI\'s response can be. \n* In AI terminology, a "token" is roughly 3/4 of a word. \n* Setting this to `2048` means the AI will stop generating text after about 1,500 words. This prevents the model from rambling indefinitely and helps control API costs (since you usually pay per token generated).\n\n---\n\n## 3. Why Someone Would Use This Approach\n\nA developer would use this exact configuration when they need **fast, reliable, and controlled factual responses**. \n\n* **Why streaming?** User experience. If a user asks a complex question, waiting 10 seconds for a 2048-token response feels broken. Streaming the text makes the application feel incredibly fast and responsive, even if the total generation time is the same.\n* **Why low temperature?** If you are building a tool that writes code, summarizes legal documents, or extracts data, you want strict adherence to facts. A temperature of `0.2` heavily reduces the chance of the AI making things up.\n* **Why a high token limit?** The developer wants to ensure the AI has enough room to give a thorough answer without getting cut off prematurely, but `2048` is a safe ceiling to prevent runaway costs.\n\n---\n\n## 4. Important Concepts and Patterns Involved\n\n### The Chat Completions API Pattern\nThe use of a `messages` array is the industry standard (pioneered by OpenAI and adopted by NVIDIA, Anthropic, and others). Instead of sending a single string of text, you send a structured conversation. This allows the AI to understand "who said what" (System, User, Assistant).\n\n### Server-Sent Events (SSE) for Streaming\nUnder the hood, when `use_stream=True` is passed, the HTTP request to the NVIDIA server stays open. The server pushes data to the client in chunks using a protocol called Server-Sent Events. The Python code likely uses a loop (like `for chunk in response:`) to catch these pieces as they arrive.\n\n### Deterministic Inference\nBy setting `temperature=0.2`, the developer is leaning into **determinism**—the idea that feeding the same input should yield nearly the sam ...

# %% [markdown]
# ## Conclusion
#
# You have successfully built a **Personalized Programming Tutor**.
#
# This project demonstrates how to:
# - Configure and use different LLM providers.
# - Design effective system prompts to create specific AI personas.
# - Implement streaming for better user experience.
# - Structure a clean, professional AI application.
#
# **Future Improvements:**
# - Add a "Follow-up Question" feature to make it a conversation.
# - Integrate syntax highlighting for the code blocks in the output.
# - Add support for uploading code files directly.
